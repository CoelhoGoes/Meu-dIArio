# %%
from connections.postgres import PostgresConnection   
from psycopg2.extras import RealDictCursor

# %%
connections = PostgresConnection().get_connection()

# %%
with connections.cursor(cursor_factory=RealDictCursor) as cur:
    cur.execute("SELECT * FROM users;")
    users = cur.fetchall()
    print(users)
# Out:
# []
